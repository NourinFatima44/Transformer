# %% [markdown]
# # importing the file

# %%
import os, glob, pickle
import numpy as np
import pandas as pd
import numpy as np
df = pd.read_csv('combined_data21.csv')
data = df.groupby('covid_status').count()
#data = data.set_index("covid_status")
#data = data.drop("no_resp_illness_exposed", axis=0)
id1=np.array(df["id"])

df.shape
df.reset_index(drop=True, inplace=True)

df.shape
# Out:
# (1486, 27)

# %% [markdown]
# # Data cleaning proc

# %%
data = df.set_index("covid_status")
df.drop(df[df.covid_status =="no_resp_illness_exposed"].index, inplace=True)
df.shape
df.drop(df[df.covid_status =="resp_illness_not_identified"].index, inplace=True)
df.shape
df.drop(df[df.id =="resp_illness_not_identified"].index, inplace=True)
df.drop(df[df.covid_status =="recovered_full"].index, inplace=True)
df.shape
#____________________-Rename
df['covid_status'] = df['covid_status'].str.replace('positive_asymp', 'Covid')
df['covid_status'] = df['covid_status'].str.replace('positive_asymp', 'Covid')
df['covid_status'] = df['covid_status'].str.replace('positive_mild', 'Covid')
df['covid_status'] = df['covid_status'].str.replace('positive_moderate', 'Covid')
df.drop(df[df.covid_status =="no_resp_illness_exposed"].index, inplace=True)
df.shape
df.drop(df[df.covid_status =="resp_illness_not_identified"].index, inplace=True)
df.shape
df.drop(df[df.id =="resp_illness_not_identified"].index, inplace=True)
df.drop(df[df.covid_status =="recovered_full"].index, inplace=True)

# %%
data = df.groupby('covid_status').count()
data

#df.shape
#data1 = {'id': df.id, 'covid_status':df.covid_status}       
#df_c = pd.DataFrame(data1).reset_index()
#df_c.to_csv(r'E:\Coswara-Data\Spectogram\updated.csv', index = False)
# Out:
#                 id     a    ep     g   l_c   l_l   l_s   rU  asthma  cough  \
# covid_status
# Covid          107   107   107   107   107    80   107  106       2     47
# healthy       1186  1186  1186  1186  1186  1054  1186  586      15     38
#
#               ...  bd  st  fever  ftg  mp  loss_of_smell  test_status  \
# covid_status  ...
# Covid         ...  12  30     38   17  13             12           12
# healthy       ...   4   9     11    3   5              2           51
#
#               pneumonia  diarrhoea  cld
# covid_status
# Covid                 2          0    1
# healthy               0          1    1
#
# [2 rows x 26 columns]

# %%
import seaborn as sns
sns.countplot(df['covid_status'])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='covid_status', ylabel='count'>

# %% [markdown]
# # removing the empty folder and those whose features are less then 9

# %%
#deleted whose files are empty 
for i in range(len(id1)):
    os.chdir(r'E://Coswara-Data//done/'+id1[i])
    myFiles = glob.glob('*.wav')
   # print(len(myFiles))
    if(len(myFiles)<9):
        print(len(myFiles))
        #df.drop(df[df.id ==id1[i]].index, inplace=True)

# %%
id1=np.array(df["id"])
len(id1)

# %% [markdown]
# # Creaing the list for  5 features for each 9 sound files

# %%
#starat over her w
#cough-heavy
import numpy as np
import matplotlib.pyplot as plt
import os
import librosa
from scipy.io import wavfile
import scipy.io
import IPython.display as ipd
import matplotlib.pyplot as plt
import librosa.display
import glob
import os
#1
countingfast_MF=[]
countingfast_SR=[]
countingfast_ZC=[]
countingfast_RM=[]
countingfast_SC=[]

#2
countingnormal_MF=[]
countingnormal_SR=[]
countingnormal_ZC=[]
countingnormal_RM=[]
countingnormal_SC=[]

#3
breathingdeep_MF=[]
breathingdeep_SR=[]
breathingdeep_ZC=[]
breathingdeep_RM=[]
breathingdeep_SC=[]

#4
breathingshallow_MF=[]
breathingshallow_SR=[]
breathingshallow_ZC=[]
breathingshallow_RM=[]
breathingshallow_SC=[]
#5
vowelo_MF=[]
vowelo_SR=[]
vowelo_ZC=[]
vowelo_RM=[]
vowelo_SC=[]

#6
vowela_MF=[]
vowela_SR=[]
vowela_ZC=[]
vowela_RM=[]
vowela_SC=[]


#7
vowele_MF=[]
vowele_SR=[]
vowele_ZC=[]
vowele_RM=[]
vowele_SC=[]


#8
coughheavy_MF=[]
coughheavy_SR=[]
coughheavy_ZC=[]
coughheavy_RM=[]
coughheavy_SC=[]

#9
coughshallow_MF=[]
coughshallow_SR=[]
coughshallow_ZC=[]
coughshallow_RM=[]
coughshallow_SC=[]

# %% [markdown]
# # Cough shallow data

# %% [markdown]
# # Cough havey data

# %%
print(len(coughheavy_MF),len(coughheavy_SR),len(coughheavy_ZC) ,len(coughheavy_RM) ,len(coughheavy_SC), len(ccidm3))
# Out:
# 9999 9999 9999 9999 9999 10008

# %% [markdown]
# # Appending the files if the sound file is empty

# %%
import numpy as np
dele=[]
for i  in range(0,30):
    dele.append(0)
dele=np.array(dele)
dele=dele.reshape(1,-1)
dele.shape
# Out:
# (1, 30)

# %% [markdown]
# # Code for extracting the features

# %%
ccidm=[]
ccidm1=[]
ccidm2=[]
ccidm3=[]
ccidm4=[]
ccidm5=[]
ccidm6=[]
ccidm7=[]
ccidm8=[]
ccidm9=[]
cme=[]
for i in range(len(id1)):
    os.chdir(r'E://Coswara-Data//done/'+id1[i])
    myFiles = glob.glob('*.wav')
    for j in  range (len(myFiles)):
        try:
            ccidm.append(id1[i])
            for k in range(9):
                if(myFiles[k]=='breathing-deep.wav'):
                    print("b")
                    ccidm1.append(id1[i])
                    x, sr = librosa.load(str(myFiles[k]))
                    if(librosa.get_duration(x)!=0):
                        mfccs = librosa.feature.mfcc(y=x, sr=sr , n_mfcc=1)
                        breathingdeep_MF.append(np.array(mfccs))
                        
                        spectral_rolloff = librosa.feature.spectral_rolloff(x, sr=sr)
                        breathingdeep_SR.append(np.array(spectral_rolloff))
                        
                        spectral_centroids = librosa.feature.spectral_centroid(x, sr=sr)
                        breathingdeep_SC.append(np.array(spectral_centroids))
                        
                        zero_crossings=librosa.feature.zero_crossing_rate(x)
                        breathingdeep_ZC.append(np.array(zero_crossings))
                        
                        rmse=librosa.feature.rms(y=x)
                        breathingdeep_RM.append(np.array(rmse))
                    
                    else:
                        breathingdeep_MF.append(dele)
                        breathingdeep_SR.append(dele)
                        breathingdeep_SC.append(dele)
                        breathingdeep_ZC.append(dele)
                        breathingdeep_RM.append(dele)
                        print(id1[i],myFiles[k] )
                       
                elif(myFiles[k]=='breathing-shallow.wav'):
                    print("D")
                    ccidm2.append(id1[i])
                    x, sr = librosa.load(str(myFiles[k]))
                    if(librosa.get_duration(x)!=0):
                        mfccs = librosa.feature.mfcc(y=x, sr=sr,n_mfcc=1)
                        breathingshallow_MF.append(np.array(mfccs))
                        
                        spectral_rolloff = librosa.feature.spectral_rolloff(x, sr=sr)
                        breathingshallow_SR.append(np.array(spectral_rolloff))
                        
                        spectral_centroids = librosa.feature.spectral_centroid(x, sr=sr)
                        breathingshallow_SC.append(np.array(spectral_centroids))
                        
                        zero_crossings=librosa.feature.zero_crossing_rate(x)
                        breathingshallow_ZC.append(np.array(zero_crossings))
                        
                        rmse=librosa.feature.rms(y=x)
                        breathingshallow_RM.append(np.array(rmse))
                
                    else:
                        breathingshallow_MF.append(dele)
                        breathingshallow_SR.append(dele)
                        breathingshallow_SC.append(dele)
                        breathingshallow_ZC.append(dele)
                        breathingshallow_RM.append(dele)
                        print(id1[i],myFiles[k] )
                     
                elif(myFiles[k]=='cough-heavy.wav'):
                    ccidm3.append(id1[i])
                    x, sr = librosa.load(str(myFiles[k]))
                    if(librosa.get_duration(x)!=0):
                        mfccs = librosa.feature.mfcc(y=x, sr=sr,n_mfcc=1)
                        coughheavy_MF.append(np.array(mfccs))
                        
                        spectral_rolloff = librosa.feature.spectral_rolloff(x, sr=sr)
                        coughheavy_SR.append(np.array(spectral_rolloff))
                        
                        spectral_centroids = librosa.feature.spectral_centroid(x, sr=sr)
                        coughheavy_SC.append(np.array(spectral_centroids))
                        
                        zero_crossings=librosa.feature.zero_crossing_rate(x)
                        coughheavy_ZC.append(np.array(zero_crossings))
                        
                        rmse=librosa.feature.rms(y=x)
                        coughheavy_RM.append(np.array(rmse))
                       
                    else:
                        coughheavy_MF.append(dele)
                        coughheavy_SR.append(dele)
                        coughheavy_SC.append(dele)
                        coughheavy_ZC.append(dele)
                        coughheavy_RM.append(dele)
                        print(id1[i],myFiles[k] )
                      
                        
                elif(myFiles[k]=='cough-shallow.wav'):
                    x, sr = librosa.load(str(myFiles[k]))
                    ccidm4.append(id1[i])
                    if(librosa.get_duration(x)!=0):
                          
                        mfccs = librosa.feature.mfcc(y=x, sr=sr,n_mfcc=1)
                        coughshallow_MF.append(np.array(mfccs))
                        
                        spectral_rolloff = librosa.feature.spectral_rolloff(x, sr=sr)
                        coughshallow_SR.append(np.array(spectral_rolloff))
                        
                        spectral_centroids = librosa.feature.spectral_centroid(x, sr=sr)
                        coughshallow_SC.append(np.array(spectral_centroids))
                        
                        zero_crossings=librosa.feature.zero_crossing_rate(x)
                        coughshallow_ZC.append(np.array(zero_crossings))
                        
                        rmse=librosa.feature.rms(y=x)
                        coughshallow_RM.append(np.array(rmse))
                        
                        
                    else:
                        coughshallow_MF.append(dele)
                        coughshallow_SR.append(dele)
                        coughshallow_SC.append(dele)
                        coughshallow_ZC.append(dele)
                        coughshallow_RM.append(dele)
                        print(id1[i],myFiles[k] )
                        
                elif(myFiles[k]=='counting-fast.wav'): 
                    x, sr = librosa.load(str(myFiles[k]))
                    ccidm5.append(id1[i])
                    if(librosa.get_duration(x)!=0):
                        mfccs = librosa.feature.mfcc(y=x, sr=sr,n_mfcc=1)
                        countingfast_MF.append(np.array(mfccs))
                        
                        spectral_rolloff = librosa.feature.spectral_rolloff(x, sr=sr)
                        countingfast_SR.append(np.array(spectral_rolloff))
                        
                        spectral_centroids = librosa.feature.spectral_centroid(x, sr=sr)
                        countingfast_SC.append(np.array(spectral_centroids))
                        
                        zero_crossings=librosa.feature.zero_crossing_rate(x)
                        countingfast_ZC.append(np.array(zero_crossings))
                        
                        rmse=librosa.feature.rms(y=x)
                        countingfast_RM.append(np.array(rmse))
                        
                    else:
                        countingfast_MF.append(dele)
                        countingfast_SR.append(dele)
                        countingfast_SC.append(dele)
                        countingfast_ZC.append(dele)
                        countingfast_RM.append(dele)
                        print(id1[i],myFiles[k] )
                        
                        
                elif(myFiles[k]=='counting-normal.wav'):
                    ccidm6.append(id1[i])
                    x, sr = librosa.load(str(myFiles[k]))
                    if(librosa.get_duration(x)!=0):
                        mfccs = librosa.feature.mfcc(y=x, sr=sr,n_mfcc=1)
                        countingnormal_MF.append(np.array(mfccs))
                        
                        spectral_rolloff = librosa.feature.spectral_rolloff(x, sr=sr)
                        countingnormal_SR.append(np.array(spectral_rolloff))
                        
                        spectral_centroids = librosa.feature.spectral_centroid(x, sr=sr)
                        countingnormal_SC.append(np.array(spectral_centroids))
                        
                        zero_crossings=librosa.feature.zero_crossing_rate(x)
                        countingnormal_ZC.append(np.array(zero_crossings))
                        
                        rmse=librosa.feature.rms(y=x)
                        countingnormal_RM.append(np.array(rmse))
                        
                    else:
                        countingnormal_MF.append(dele)
                        countingnormal_SR.append(dele)
                        countingnormal_SC.append(dele)
                        countingnormal_ZC.append(dele)
                        countingnormal_RM.append(dele)
                        print(id1[i],myFiles[k] )
                        
                        
                elif(myFiles[k]=='vowel-a.wav'):
                    ccidm7.append(id1[i])
                    x, sr = librosa.load(str(myFiles[k]))
                    if(librosa.get_duration(x)!=0):
                          
                        mfccs = librosa.feature.mfcc(y=x, sr=sr,n_mfcc=1)
                        vowela_MF.append(np.array(mfccs))
                        
                        spectral_rolloff = librosa.feature.spectral_rolloff(x, sr=sr)
                        vowela_SR.append(np.array(spectral_rolloff))
                    
                        spectral_centroids = librosa.feature.spectral_centroid(x, sr=sr)
                        vowela_SC.append(np.array(spectral_centroids))
                        
                        zero_crossings=librosa.feature.zero_crossing_rate(x)
                        vowela_ZC.append(np.array(zero_crossings))
                        
                        rmse=librosa.feature.rms(y=x)
                        vowela_RM.append(np.array(rmse))
                        
                    else:
                        vowela_MF.append(dele)
                        vowela_SR.append(dele)
                        vowela_SC.append(dele)
                        vowela_ZC.append(dele)
                        vowela_RM.append(dele)
                        print(id1[i],myFiles[k] )
                       
                    
                elif(myFiles[k]=='vowel-e.wav'):
                    ccidm8.append(id1[i])
                    x, sr = librosa.load(str(myFiles[k]))
                    if(librosa.get_duration(x)!=0):
                          
                        mfccs = librosa.feature.mfcc(y=x, sr=sr,n_mfcc=1)
                        vowele_MF.append(np.array(mfccs))
                        
                        spectral_rolloff = librosa.feature.spectral_rolloff(x, sr=sr)
                        vowele_SR.append(np.array(spectral_rolloff))
                        
                        spectral_centroids = librosa.feature.spectral_centroid(x, sr=sr)
                        vowele_SC.append(np.array(spectral_centroids))
                        
                        zero_crossings=librosa.feature.zero_crossing_rate(x)
                        vowele_ZC.append(np.array(zero_crossings))
                        
                        rmse=librosa.feature.rms(y=x)
                        vowele_RM.append(np.array(rmse))
                       
                    else:
                        vowele_MF.append(dele)
                        vowele_SR.append(dele)
                        vowele_SC.append(dele)
                        vowele_ZC.append(dele)
                        vowele_RM.append(dele)
                        print(id1[i],myFiles[k] )
                        
                elif(myFiles[k]=='vowel-o.wav'):
                    ccidm9.append(id1[i])
                    if(librosa.get_duration(x)!=0):
                        x, sr = librosa.load(str(myFiles[k]))  
                        mfccs = librosa.feature.mfcc(y=x, sr=sr,n_mfcc=1)
                        vowelo_MF.append(np.array(mfccs))
                        
                        spectral_rolloff = librosa.feature.spectral_rolloff(x, sr=sr)
                        vowelo_SR.append(np.array(spectral_rolloff))
                        
                        spectral_centroids = librosa.feature.spectral_centroid(x, sr=sr)
                        vowelo_SC.append(np.array(spectral_centroids))
                        
                        zero_crossings=librosa.feature.zero_crossing_rate(x)
                        vowelo_ZC.append(np.array(zero_crossings))
                        
                        rmse=librosa.feature.rms(y=x)
                        vowelo_RM.append(np.array(rmse))
                       
                    else:
                        vowelo_MF.append(dele)
                        vowelo_SR.append(dele)
                        vowelo_SC.append(dele)
                        vowelo_ZC.append(dele)
                        vowelo_RM.append(dele)
                        print(id1[i],myFiles[k] )
                       
                else:
                    print("not match")
                
        except Exception as e:
            print("Error encountered while parsing file: ", str(id1[i]))
            ccidm.remove(str(id1[i]))
            
            #th.drop(th[th.id ==cid[i]].index, inplace=True)
# Out:
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# b
# D
# Error encountered while parsing file:  C3luMlCgAFZqGmGjFscXe9fVHSG3
# b
# D
# Error encountered while parsing file:  C3luMlCgAFZqGmGjFscXe9fVHSG3
# b
# D
# Error encountered while parsing file:  C3luMlCgAFZqGmGjFscXe9fVHSG3
# b
# D
# ...

# %%
data1 = {'id': ccidm} 
df_c = pd.DataFrame(data1).reset_index()
df_c.to_csv(r'E:\Coswara-Data\id.csv', index = False)

# %%
d= pd.read_csv('E:\Coswara-Data\id.csv')
d.groupby("id").count()<9
# Out:
#                               index
# id
# 01OCEf1yB4czsq8ygRoT51s96Ba2  False
# 05bieNLXPuaIWEVaX81EkbbjVrh1  False
# 0EAAFsDWfTcrhktHy78LS6nf19G3  False
# 0Ha52POVIxTKEPqI1eGpIoMHUd52  False
# 0KOy96zEUfdMY4rZzwrDT0gMPDa2  False
# ...                             ...
# zt2ssuTmZESDhYPW40dyo5RW2sT2  False
# zw0pYfsZxDShQGV2HTuont8wU8V2  False
# zxRJaPEBRGX8uH4egnctWAuIuy32  False
# zyX6JZlkhxayEeUP5SL4L6WA1h13  False
# zzh7tK9CrZacOddJTG9YQwCZz4f2  False
#
# [1103 rows x 1 columns]

# %%
print(len(chm), len(chrm),len(chz),len(crsm),len(chc), len(ccid))
#chrm= []
#chz=[]
#chro=[]
#chc=[]
#crsm=[]
#len(th.id)
#a=(th.loc[th['id'] == 'exj2e14KykUjLNwbOGgOgFieo8a2' ,'covid_status'])
#print(np.array(a))
#th.covid_status.iloc[4]
len(th.id)
print(c)
print(1007-1032)
#data1 = {'id': ccid, }       
#df_c.to_csv(r'E:\Coswara-Data\coswara.csv', index = False)

# %%
#for k in range(len(chm)):
    #print(chm[k].shape)
list4=[]
for i in range(0,len(chc)):
    chc[i]=chc[i].reshape(-1)
    print(chc[i].shape)
    list4.append(int(chc[i].shape[0]))

# %%
#x1=np.array(x2)
#shape
maxlen=chrm_m

from keras.preprocessing import sequence
chm = sequence.pad_sequences(chm, maxlen=maxlen)
print('input_train shape:', chrm_t.shape)
#for i in x1:rint(input_train)
    #for k in range(max1):
        #x1[k].append(0)
        
#for i in range(0,len(x1)):
   # x1[i]=x1[i].reshape(-1)
    #print(x1[i].shape)
   # list1.append(int(x1[i].shape[0]))
#print(x1[0].shape)
#list1.append(int(x1[i].shape[0]))

       
#df = pd.DataFrame(data)

#print(x1[4])

# %%
import IPython.display as ipd
import matplotlib.pyplot as plt
import librosa.display
print(len(x2)-len(y2))
for i in range(500,len(x2)):
    X = librosa.stft(x2[i])
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(14, 5))
    librosa.display.specshow(Xdb, sr=sample_rate, x_axis='time', y_axis='hz') 
    #plt.colorbar()
    if y2[i]=='Covid':
        filename  = 'E:/Coswara-Data/Spectogram/coughshallow/Covid/'+ str(i) + "Cough-Heavy"+str(y2[i]) + '.jpg'
        plt.savefig(filename, dpi=400, bbox_inches='tight',pad_inches=0)
    else:
        filename  = 'E:/Coswara-Data/Spectogram/coughshallow/healthy/'+ str(i) + "Cough-Heavy"+str(y2[i]) + '.jpg'
        plt.savefig(filename, dpi=400, bbox_inches='tight',pad_inches=0)

# %%
# !pip install tqdm

# %%
X = librosa.stft(x1[0])
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sample_rate, x_axis='time', y_axis='hz') 
    #plt.colorbar()
if y1[0]=='Covid':
        filename  = 'E:/Coswara-Data/Spectogram/'+ str(0) + "Cough-Heavy"+str(y1[0]) + '.jpg'
        plt.savefig(filename, dpi=400, bbox_inches='tight',pad_inches=0)
else:
        filename  = 'E:/Coswara-Data/Spectogram/'+ str(0) + "Cough-Heavy"+str(y1[0]) + '.jpg'
        plt.savefig(filename, dpi=400, bbox_inches='tight',pad_inches=0)

# %%
#converting spectogram into audio
import IPython.display as ipd
sr = 22050 # sample rate
T = 2.0    # seconds
t = np.linspace(0, T, int(T*sr), endpoint=False) # time variable
#x = 0.5*np.sin(2*np.pir*220*t)# p
ipd.Audio(x1[12], rate=sr) # load a NumPy array
#Saving the audio
#librosa.output.write_wav('tone_220.wav', x, sr)

# %%
a=b=c1=d=e1=f=g=i1=k1=x1=0
lm=0
dele=[]
for i in range(len(id1)):
    os.chdir(r'E://Coswara-Data//done/'+id1[i])
    myFiles = glob.glob('*.wav')
    #print(myFiles)
    #print(len(myFiles), myFiles)
    for j in  range (len(myFiles)):
        lm+=1
        #print(myFiles[j])
        for k in range(len(myFiles)):
            if(len(myFiles[k])==0):
                pass
                
            else:
                if(myFiles[k]=='breathing-deep.wav'):
                    x, sr = librosa.load(myFiles[k])
                    if(librosa.get_duration(x)==0):
                        dele.append(id1[i])
                    #a+=1
                    
                elif(myFiles[k]=='breathing-shallow.wav'):
                    x, sr = librosa.load(myFiles[k])
                    if(librosa.get_duration(x)==0):
                        dele.append(id1[i])
                    
                    
                elif(myFiles[k]=='cough-heavy.wav'):
                    
                    x, sr = librosa.load(myFiles[k])
                    if(librosa.get_duration(x)==0):
                        dele.append(id1[i])
                    
                elif(myFiles[k]=='cough-shallow.wav'): 
                    
                    x, sr = librosa.load(myFiles[k])
                    if(librosa.get_duration(x)==0):
                        dele.append(id1[i])
                    
                elif(myFiles[k]=='counting-fast.wav'): 
                    x, sr = librosa.load(myFiles[k])
                    if(librosa.get_duration(x)==0):
                        dele.append(id1[i])
                    
                    
                elif(myFiles[k]=='counting-normal.wav'): 
                    x, sr = librosa.load(myFiles[k])
                    if(librosa.get_duration(x)==0):
                        dele.append(id1[i])
                    
                elif(myFiles[k]=='vowel-a.wav'):
                    x, sr = librosa.load(myFiles[k])
                    if(librosa.get_duration(x)==0):
                        dele.append(id1[i])
                    
                    
                elif(myFiles[k]=='vowel-e.wav'):
                    x, sr = librosa.load(myFiles[k])
                    if(librosa.get_duration(x)==0):
                        dele.append(id1[i])
                    
                    
                elif(myFiles[k]=='vowel-o.wav'):
                    x, sr = librosa.load(myFiles[k])
                    if(librosa.get_duration(x)==0):
                        dele.append(id1[i])
                else:
                    x+=1
            

                

#1
#counting-fast_MF
#counting-fast_SR
#counting-fast_ZC
#counting-fast_RM
#counting-fast_SC

#2
#counting-normal_MF
#counting-normal_SR
#counting-normal_ZC
#counting-normal_RM
#counting-normal_SC

#3
#breathing-deep_MF
#breathing-deep_SR
#breathing-deep_ZC
#breathing-deep_RM
#breathing-deep_SC

#4
#breathing-shallow_MF
#breathing-shallow_SR
#breathing-shallow_ZC
#breathing-shallow_RM
#breathing-shallow_SC
#5
#vowel-o_MF
#vowel-o_SR
#vowel-o_ZC
#vowel-o_RM
#vowel-o_SC

#6
#vowel-a_MF
#vowel-a_SR
#vowel-a_ZC
#vowel-a_RM
#vowel-a_SC


#7
#vowel-e_MF
#vowel-e_SR
#vowel-e_ZC
#vowel-e_RM
#vowel-e_SC


#8
#cough-heavy_MF
#cough-heavy_SR
#cough-heavy_ZC
#cough-heavy_RM
#cough-heavy_SC

#9
#cough-shallow_MF
#cough-shallow_SR
#cough-shallow_ZC
#cough-shallow_RM
#cough-shallow_SC

# %%
import os
#print(len(dele))
print(os.chdir(r'E://Coswara-Data//done//'))
# Out:
# None

# %%
id2=[]
id2=os.listdir()
import numpy as np
id2=np.array(id2, np.dtype(object))
#id2=id2.reshape(-1,1)
#id2.shape
#id2=id2.astype(str)

# %%
em=[]
for i in range(len(id2)):
    os.chdir(r'E://Coswara-Data//done//'+id2[i])
    myFiles = glob.glob('*.wav')
    if(len(myFiles )==0):
        em.append(id2)
        #k=myFiles[i]
        #os.rmdir(str(k))

# %%
df.dtypes
# Out:
# index            int64
# id              object
# covid_status    object
# dtype: object
